# %%
# load all data
import numpy as np
import zarr, nrrd

# file paths to tutorial data N5 files
fix_path = '/groups/scicompsoft/home/fleishmang/source/bigstream/resources/fix.n5'
mov_path = '/groups/scicompsoft/home/fleishmang/source/bigstream/resources/mov.n5'
fix_zarr = zarr.open(store=zarr.N5Store(fix_path), mode='r')
mov_zarr = zarr.open(store=zarr.N5Store(mov_path), mode='r')

# get pointers to the low res scale level
fix_lowres = fix_zarr['/lowres']
mov_lowres = mov_zarr['/lowres']

# we need the voxel spacings for the low res data sets
fix_meta = fix_lowres.attrs.asdict()
mov_meta = mov_lowres.attrs.asdict()
fix_lowres_spacing = np.array(fix_meta['pixelResolution']) * fix_meta['downsamplingFactors']
mov_lowres_spacing = np.array(mov_meta['pixelResolution']) * mov_meta['downsamplingFactors']
fix_lowres_spacing = fix_lowres_spacing[::-1]  # put in zyx order
mov_lowres_spacing = mov_lowres_spacing[::-1]

# sanity check: print the voxel spacings and lowres dataset shapes
print(fix_lowres_spacing, mov_lowres_spacing)
print(fix_lowres.shape, mov_lowres.shape)

# get pointers to the high res scale level
fix_highres = fix_zarr['/highres']
mov_highres = mov_zarr['/highres']

# we need the voxel spacings for the high res data sets
fix_meta = fix_highres.attrs.asdict()
mov_meta = mov_highres.attrs.asdict()
fix_highres_spacing = np.array(fix_meta['pixelResolution']) * fix_meta['downsamplingFactors']
mov_highres_spacing = np.array(mov_meta['pixelResolution']) * mov_meta['downsamplingFactors']
fix_highres_spacing = fix_highres_spacing[::-1]
mov_highres_spacing = mov_highres_spacing[::-1]

# sanity check: print the voxel spacings and lowres dataset shapes
print(fix_highres_spacing, mov_highres_spacing)
print(fix_highres.shape, mov_highres.shape)
# Out:
# [1.68 1.84 1.84] [1.68 1.84 1.84]
# (149, 241, 456) (144, 241, 456)
# [0.84 0.92 0.92] [0.84 0.92 0.92]
# (298, 483, 913) (288, 483, 912)

# %%
from bigstream.application_pipelines import easifish_registration_pipeline

local_deform_kwargs = {
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':1,
    }
}
cluster_kwargs = {'project':'scicompsoft'}

affine, deform, aligned = easifish_registration_pipeline(
    fix_lowres, fix_highres, mov_lowres, mov_highres,
    fix_lowres_spacing, fix_highres_spacing,
    mov_lowres_spacing, mov_highres_spacing,
    blocksize=[128,]*3,
    write_directory='./',
    local_deform_kwargs=local_deform_kwargs,
    cluster_kwargs=cluster_kwargs,
)
# Out:
# /groups/scicompsoft/home/fleishmang/bin/miniconda3/envs/CircuitSeeker/lib/python3.8/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile
# IBM Spectrum LSF 10.1.0.0 build 601088, Apr 15 2022
# Copyright International Business Machines Corp. 1992, 2016.
# US Government Users Restricted Rights - Use, duplication or disclosure restricted by GSA ADP Schedule Contract with IBM Corp.
#
#   binary type: linux3.10-glibc2.17-x86_64
# LEVEL:  0  ITERATION:  0  METRIC:  -0.45814196047278427
# LEVEL:  0  ITERATION:  1  METRIC:  -0.46185173508006
# LEVEL:  0  ITERATION:  90  METRIC:  -0.5091674538238435
# LEVEL:  0  ITERATION:  91  METRIC:  -0.5092142034516426
# LEVEL:  0  ITERATION:  92  METRIC:  -0.509216189584641
# LEVEL:  0  ITERATION:  93  METRIC:  -0.5092692290968142
# LEVEL:  0  ITERATION:  94  METRIC:  -0.5092657332979336
# LEVEL:  0  ITERATION:  95  METRIC:  -0.5093147763734807
# LEVEL:  0  ITERATION:  96  METRIC:  -0.5093185071494332
# LEVEL:  0  ITERATION:  97  METRIC:  -0.5093294135759077
# LEVEL:  0  ITERATION:  98  METRIC:  -0.5093451798797407
# LEVEL:  0  ITERATION:  99  METRIC:  -0.5093668808403666
# LEVEL:  0  ITERATION:  100  METRIC:  -0.5093832520211125
# LEVEL:  0  ITERATION:  101  METRIC:  -0.5093982431109599
# LEVEL:  0  ITERATION:  102  METRIC:  -0.5094087199070356
# LEVEL:  0  ITERATION:  103  METRIC:  -0.5094233868828698
# LEVEL:  0  ITERATION:  104  METRIC:  -0.5094362632815292
# LEVEL:  0  ITERATION:  105  METRIC:  -0.5094517777421594
# LEVEL:  0  ITERATION:  106  METRIC:  -0.50946091863283
# LEVEL:  0  ITERATION:  107  METRIC:  -0.5094730087572727
# LEVEL:  0  ITERATION:  108  METRIC:  -0.5094845376039574
# LEVEL:  0  ITERATION:  109  METRIC:  -0.5094973190389099
# LEVEL:  0  ITERATION:  110  METRIC:  -0.5095113266061492
# LEVEL:  0  ITERATION:  111  METRIC:  -0.5095240123974473
# LEVEL:  0  ITERATION:  112  METRIC:  -0.5095386844496353
# LEVEL:  0  ITERATION:  113  METRIC:  -0.5095482922903691
# LEVEL:  0  ITERATION:  114  METRIC:  -0.5095602501030921
# LEVEL:  0  ITERATION:  115  METRIC:  -0.5095674961472749
# LEVEL:  0  ITERATION:  116  METRIC:  -0.5095784583376411
# LEVEL:  0  ITERATION:  117  METRIC:  -0.509583314755252
# LEVEL:  0  ITERATION:  118  METRIC:  -0.5095925119564693
# LEVEL:  0  ITERATION:  119  METRIC:  -0.509597695261988
# LEVEL:  0  ITERATION:  120  METRIC:  -0.5096061592381336
# LEVEL:  0  ITERATION:  121  METRIC:  -0.5096178264521583
# LEVEL:  0  ITERATION:  122  METRIC:  -0.5096245047607811
# LEVEL:  0  ITERATION:  123  METRIC:  -0.5096347203008781
# LEVEL:  0  ITERATION:  124  METRIC:  -0.5096431954791367
# LEVEL:  0  ITERATION:  125  METRIC:  -0.5096479335075216
# LEVEL:  0  ITERATION:  126  METRIC:  -0.5096586029190395
# LEVEL:  0  ITERATION:  127  METRIC:  -0.5096636256486675
# LEVEL:  0  ITERATION:  128  METRIC:  -0.5096711551089135
# LEVEL:  0  ITERATION:  129  METRIC:  -0.509671599889858
# LEVEL:  0  ITERATION:  130  METRIC:  -0.509680769397874
# LEVEL:  0  ITERATION:  131  METRIC:  -0.5096803231230047
# LEVEL:  0  ITERATION:  132  METRIC:  -0.5096939514517252
# LEVEL:  0  ITERATION:  133  METRIC:  -0.5096832004046218
# LEVEL:  0  ITERATION:  134  METRIC:  -0.5096930428922364
# LEVEL:  0  ITERATION:  135  METRIC:  -0.5096963343789521
# LEVEL:  0  ITERATION:  136  METRIC:  -0.5096985480562537
# LEVEL:  0  ITERATION:  137  METRIC:  -0.5097053285202905
# LEVEL:  0  ITERATION:  138  METRIC:  -0.5097062599050466
# LEVEL:  0  ITERATION:  139  METRIC:  -0.5097065341575029
# LEVEL:  0  ITERATION:  140  METRIC:  -0.5097091262880035
# LEVEL:  0  ITERATION:  141  METRIC:  -0.5097118115580118
# LEVEL:  0  ITERATION:  142  METRIC:  -0.5097138723496598
# LEVEL:  0  ITERATION:  143  METRIC:  -0.5097140698975877
# LEVEL:  0  ITERATION:  144  METRIC:  -0.5097168842507488
# LEVEL:  0  ITERATION:  145  METRIC:  -0.5097187543024696
# LEVEL:  0  ITERATION:  146  METRIC:  -0.5097178910182579
# LEVEL:  0  ITERATION:  147  METRIC:  -0.50971778723236
# LEVEL:  0  ITERATION:  148  METRIC:  -0.5097211147084018
# LEVEL:  0  ITERATION:  149  METRIC:  -0.5097219704124959
# LEVEL:  0  ITERATION:  150  METRIC:  -0.509722868808422
# LEVEL:  0  ITERATION:  151  METRIC:  -0.5097229399078755
# LEVEL:  0  ITERATION:  152  METRIC:  -0.5097223881106114
# LEVEL:  0  ITERATION:  153  METRIC:  -0.5097235058101183
# LEVEL:  0  ITERATION:  154  METRIC:  -0.5097244887035681
# LEVEL:  0  ITERATION:  155  METRIC:  -0.5097259018489112
# LEVEL:  0  ITERATION:  156  METRIC:  -0.5097241831446228
# LEVEL:  0  ITERATION:  157  METRIC:  -0.5097223707280951
# LEVEL:  0  ITERATION:  158  METRIC:  -0.5097222373325123
# LEVEL:  0  ITERATION:  159  METRIC:  -0.5097220499775572
# LEVEL:  0  ITERATION:  160  METRIC:  -0.5097221592157553
# LEVEL:  0  ITERATION:  161  METRIC:  -0.5097215664949493
# LEVEL:  0  ITERATION:  162  METRIC:  -0.509722720268899
# LEVEL:  0  ITERATION:  163  METRIC:  -0.5097227667111802
# LEVEL:  0  ITERATION:  164  METRIC:  -0.5097228943583996
# LEVEL:  0  ITERATION:  165  METRIC:  -0.5097234897280931
# LEVEL:  0  ITERATION:  166  METRIC:  -0.5097231687777375
# LEVEL:  0  ITERATION:  167  METRIC:  -0.5097243369831534
# LEVEL:  0  ITERATION:  168  METRIC:  -0.5097235911452918
# LEVEL:  0  ITERATION:  169  METRIC:  -0.5097204809036017
# LEVEL:  0  ITERATION:  170  METRIC:  -0.5097224286359691
# LEVEL:  0  ITERATION:  171  METRIC:  -0.5097209717779146
# LEVEL:  0  ITERATION:  172  METRIC:  -0.5097226723004942
# LEVEL:  0  ITERATION:  173  METRIC:  -0.509716576542342
# LEVEL:  0  ITERATION:  174  METRIC:  -0.5097212209626028
# LEVEL:  0  ITERATION:  175  METRIC:  -0.5097211617425134
# LEVEL:  0  ITERATION:  176  METRIC:  -0.5097204024984645
# LEVEL:  0  ITERATION:  177  METRIC:  -0.5097211315306311
# LEVEL:  0  ITERATION:  178  METRIC:  -0.5097208011932945
# LEVEL:  0  ITERATION:  179  METRIC:  -0.5097187495448418
# LEVEL:  0  ITERATION:  180  METRIC:  -0.5097178980358639
# LEVEL:  0  ITERATION:  181  METRIC:  -0.5097182427984577
# LEVEL:  0  ITERATION:  182  METRIC:  -0.5097184599344694
# LEVEL:  0  ITERATION:  183  METRIC:  -0.5097191467344424
# LEVEL:  0  ITERATION:  184  METRIC:  -0.5097183102699295
# LEVEL:  0  ITERATION:  185  METRIC:  -0.509717538252695
# LEVEL:  0  ITERATION:  186  METRIC:  -0.5097182578397306
# LEVEL:  0  ITERATION:  187  METRIC:  -0.5097178423975847
# LEVEL:  0  ITERATION:  188  METRIC:  -0.5097173000953371
# LEVEL:  0  ITERATION:  189  METRIC:  -0.5097183469134305
# LEVEL:  0  ITERATION:  190  METRIC:  -0.5097192371760267
# LEVEL:  0  ITERATION:  191  METRIC:  -0.5097178873656951
# LEVEL:  0  ITERATION:  192  METRIC:  -0.5097164869245108
# LEVEL:  0  ITERATION:  193  METRIC:  -0.5097159221057098
# LEVEL:  0  ITERATION:  194  METRIC:  -0.5097154886740841
# LEVEL:  0  ITERATION:  195  METRIC:  -0.509713193724681
# LEVEL:  0  ITERATION:  196  METRIC:  -0.5097122259815509
# LEVEL:  0  ITERATION:  197  METRIC:  -0.5097114357342881
# LEVEL:  0  ITERATION:  198  METRIC:  -0.5097137291097822
# LEVEL:  0  ITERATION:  199  METRIC:  -0.5097123958957643
# LEVEL:  0  ITERATION:  200  METRIC:  -0.5097128240759526
# LEVEL:  0  ITERATION:  201  METRIC:  -0.5097108196503763
# LEVEL:  0  ITERATION:  202  METRIC:  -0.5097103689421438
# LEVEL:  0  ITERATION:  203  METRIC:  -0.5097091136865117
# LEVEL:  0  ITERATION:  204  METRIC:  -0.5097076484426312
# LEVEL:  0  ITERATION:  205  METRIC:  -0.5097093351984595
# LEVEL:  0  ITERATION:  206  METRIC:  -0.5097087012599668
# LEVEL:  0  ITERATION:  207  METRIC:  -0.5097083018245788
# LEVEL:  0  ITERATION:  208  METRIC:  -0.5097071928778826
# LEVEL:  0  ITERATION:  209  METRIC:  -0.5097067863253596
# LEVEL:  0  ITERATION:  210  METRIC:  -0.5097057327609756
# LEVEL:  0  ITERATION:  211  METRIC:  -0.509708172644545
# LEVEL:  0  ITERATION:  212  METRIC:  -0.5097078567393537
# LEVEL:  0  ITERATION:  213  METRIC:  -0.5097067554146109
# LEVEL:  0  ITERATION:  214  METRIC:  -0.5097062389301764
# LEVEL:  0  ITERATION:  215  METRIC:  -0.5097056538734591
# LEVEL:  0  ITERATION:  216  METRIC:  -0.5097065528482353
# LEVEL:  0  ITERATION:  217  METRIC:  -0.5097060163807039
# LEVEL:  0  ITERATION:  218  METRIC:  -0.5097055668948574
# LEVEL:  0  ITERATION:  219  METRIC:  -0.5097052000945848
# Registration succeeded
# Cluster dashboard link:  http://10.36.60.20:8787/status
# Cluster adapting between 10 and 100 workers with 1 cores per worker
# *** This cluster has an upper bound cost of 7.0 dollars per hour ***
