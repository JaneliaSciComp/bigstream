# %% [markdown]
# ## Inputs
# ---

# %%
# reading data and working with arrays
import h5py, nrrd
import numpy as np

# data paths
data_path = '/groups/scicompsoft/home/fleishmang/rnr-exm-work/validation_data/c_elegan_pair4.h5'
hdf5_file = h5py.File(data_path, 'r')
fix = hdf5_file['/fixed'][...]
mov = hdf5_file['/move'][...]

# segment paths
data_path = '/groups/scicompsoft/home/fleishmang/rnr-exm-work/validation_data/c_elegan_pair4_segmentation.h5'
hdf5_file_seg = h5py.File(data_path, 'r')
fix_seg = hdf5_file_seg['/fixed'][...]
mov_seg = hdf5_file_seg['/move'][...]

# assumed spacings (there are no provided spacings, this is a problem)
fix_spacing = np.array([0.4, 0.1625, 0.1625])
mov_spacing = np.array([0.4, 0.1625, 0.1625])

# # # write some channels
# nrrd.write('./fix.nrrd', fix.transpose(2,1,0), compression_level=2)
# nrrd.write('./mov.nrrd', mov.transpose(2,1,0), compression_level=2)
nrrd.write('./fix_seg.nrrd', fix_seg.transpose(2,1,0), compression_level=2)
nrrd.write('./mov_seg.nrrd', mov_seg.transpose(2,1,0), compression_level=2)

# %% [markdown]
# ## Masking
# ---

# %% [markdown]
# ### fixed

# %%
# tools for coarse whole brain segmentation
from bigstream import level_set
from scipy.ndimage import zoom, binary_closing, binary_dilation

# # get small mask
# fix_skip = fix[::4, ::8, ::8]
# skip_spacing = fix_spacing * [4, 8, 8]
# fix_mask_small = level_set.foreground_segmentation(
#     fix_skip, skip_spacing,
#     mask_smoothing=2,
#     iterations=[80,40,10],
#     smooth_sigmas=[24,12,6],
#     lambda2=1.0,
# )

# # enlarge and smooth mask
# fix_mask = zoom(fix_mask_small, np.array(fix.shape) / fix_skip.shape, order=0)
# fix_mask = binary_closing(fix_mask, np.ones((5,5,5))).astype(np.uint8)
# fix_mask = binary_dilation(fix_mask, np.ones((5,5,5))).astype(np.uint8)

# # write result
# nrrd.write('./fix_mask.nrrd', fix_mask.transpose(2,1,0), compression_level=2)

# load precomputed mask
fix_mask, _ = nrrd.read('./fix_mask.nrrd')
fix_mask = fix_mask.transpose(2,1,0)

# %% [markdown]
# ### moving

# %%
# tools for coarse whole brain segmentation
from bigstream import level_set
from scipy.ndimage import zoom, binary_closing, binary_dilation

# # get small mask
# mov_skip = mov[::4, ::8, ::8]
# skip_spacing = mov_spacing * [4, 8, 8]
# mov_mask_small = level_set.foreground_segmentation(
#     mov_skip, skip_spacing,
#     mask_smoothing=2,
#     iterations=[80,40,10],
#     smooth_sigmas=[24,12,6],
#     lambda2=1.0,
# )

# # enlarge and smooth mask
# mov_mask = zoom(mov_mask_small, np.array(mov.shape) / mov_skip.shape, order=0)
# mov_mask = binary_closing(mov_mask, np.ones((5,5,5))).astype(np.uint8)
# mov_mask = binary_dilation(mov_mask, np.ones((5,5,5))).astype(np.uint8)

# # save output
# nrrd.write('./mov_mask.nrrd', mov_mask.transpose(2,1,0), compression_level=2)

# load precomputed mask
mov_mask, _ = nrrd.read('./mov_mask.nrrd')
mov_mask = mov_mask.transpose(2,1,0)

# %% [markdown]
# ## Alignment
# ---

# %% [markdown]
# ### affine

# %%
# alignment functions
from bigstream.align import alignment_pipeline
from bigstream.transform import apply_transform

# define alignment steps
common_kwargs = {
    'alignment_spacing':2.0,
    'shrink_factors':(2,),
    'smooth_sigmas':(2.,),
    'optimizer_args':{
        'learningRate':0.25,
        'minStep':0.,
        'numberOfIterations':2000,
    },
}

rigid_kwargs = {
    'initial_condition':'CENTER',
}

steps = [('rigid',  {**common_kwargs, **rigid_kwargs},),]

# %%
# %%time

# run alignment
affine = alignment_pipeline(
    fix, mov,
    fix_spacing, mov_spacing,
    steps,
    # fix_mask=fix_mask,
    # mov_mask=mov_mask,
)
# Out:
# LEVEL:  0  ITERATION:  0  METRIC:  -0.21780441734752998
# LEVEL:  0  ITERATION:  1  METRIC:  -0.22041263285554596
# LEVEL:  0  ITERATION:  2  METRIC:  -0.22262948790088605
# LEVEL:  0  ITERATION:  3  METRIC:  -0.22446911878736145
# LEVEL:  0  ITERATION:  4  METRIC:  -0.22521919739174243
# LEVEL:  0  ITERATION:  5  METRIC:  -0.22535345435326667
# LEVEL:  0  ITERATION:  6  METRIC:  -0.22580398462602297
# LEVEL:  0  ITERATION:  7  METRIC:  -0.226810478821746
# LEVEL:  0  ITERATION:  8  METRIC:  -0.22817623278249166
# LEVEL:  0  ITERATION:  9  METRIC:  -0.22970292208309176
# LEVEL:  0  ITERATION:  10  METRIC:  -0.23117753500228205
# LEVEL:  0  ITERATION:  11  METRIC:  -0.23235571784515016
# LEVEL:  0  ITERATION:  12  METRIC:  -0.23321728507153366
# LEVEL:  0  ITERATION:  13  METRIC:  -0.2337062646888881
# LEVEL:  0  ITERATION:  14  METRIC:  -0.23420706393859314
# LEVEL:  0  ITERATION:  15  METRIC:  -0.2350206606224758
# LEVEL:  0  ITERATION:  16  METRIC:  -0.23622568371385724
# LEVEL:  0  ITERATION:  17  METRIC:  -0.23768162626247646
# LEVEL:  0  ITERATION:  18  METRIC:  -0.23886645025748257
# LEVEL:  0  ITERATION:  19  METRIC:  -0.23929416232722628
# LEVEL:  0  ITERATION:  20  METRIC:  -0.23956356707477836
# LEVEL:  0  ITERATION:  21  METRIC:  -0.2395129660782357
# LEVEL:  0  ITERATION:  22  METRIC:  -0.2398811169281794
# LEVEL:  0  ITERATION:  23  METRIC:  -0.2409284415744379
# LEVEL:  0  ITERATION:  24  METRIC:  -0.24206118317433567
# LEVEL:  0  ITERATION:  25  METRIC:  -0.24322892442340405
# LEVEL:  0  ITERATION:  26  METRIC:  -0.24379498275266473
# LEVEL:  0  ITERATION:  27  METRIC:  -0.24436130815683424
# LEVEL:  0  ITERATION:  28  METRIC:  -0.2452183452630038
# LEVEL:  0  ITERATION:  29  METRIC:  -0.2461315411596124
# LEVEL:  0  ITERATION:  30  METRIC:  -0.24676874866207157
# LEVEL:  0  ITERATION:  31  METRIC:  -0.24717155977006264
# LEVEL:  0  ITERATION:  32  METRIC:  -0.24748918068923886
# LEVEL:  0  ITERATION:  33  METRIC:  -0.2479661157659366
# LEVEL:  0  ITERATION:  34  METRIC:  -0.24855097250212083
# LEVEL:  0  ITERATION:  35  METRIC:  -0.24928863350200592
# LEVEL:  0  ITERATION:  36  METRIC:  -0.2501860698469621
# LEVEL:  0  ITERATION:  37  METRIC:  -0.25112980789111444
# LEVEL:  0  ITERATION:  38  METRIC:  -0.25191004410726003
# LEVEL:  0  ITERATION:  39  METRIC:  -0.2526746600591327
# LEVEL:  0  ITERATION:  40  METRIC:  -0.2534693991360119
# LEVEL:  0  ITERATION:  41  METRIC:  -0.25376637888237824
# LEVEL:  0  ITERATION:  42  METRIC:  -0.2540847068574686
# LEVEL:  0  ITERATION:  43  METRIC:  -0.254466534753746
# LEVEL:  0  ITERATION:  44  METRIC:  -0.25493336979689285
# LEVEL:  0  ITERATION:  45  METRIC:  -0.25550239268995245
# LEVEL:  0  ITERATION:  46  METRIC:  -0.25603435660401763
# LEVEL:  0  ITERATION:  47  METRIC:  -0.2566946552196896
# LEVEL:  0  ITERATION:  48  METRIC:  -0.25728733197935344
# LEVEL:  0  ITERATION:  49  METRIC:  -0.25792502944829654
# LEVEL:  0  ITERATION:  50  METRIC:  -0.25859206989432587
# LEVEL:  0  ITERATION:  51  METRIC:  -0.25944652597762763
# LEVEL:  0  ITERATION:  52  METRIC:  -0.2600707321440274
# LEVEL:  0  ITERATION:  53  METRIC:  -0.26059456118612856
# LEVEL:  0  ITERATION:  54  METRIC:  -0.26114640616498547
# LEVEL:  0  ITERATION:  55  METRIC:  -0.26139779447948447
# LEVEL:  0  ITERATION:  56  METRIC:  -0.2618227367113281
# LEVEL:  0  ITERATION:  57  METRIC:  -0.26230367741976796
# LEVEL:  0  ITERATION:  58  METRIC:  -0.2627558215866282
# LEVEL:  0  ITERATION:  59  METRIC:  -0.26327856198133737
# LEVEL:  0  ITERATION:  60  METRIC:  -0.2638699080587318
# LEVEL:  0  ITERATION:  61  METRIC:  -0.26441525273617117
# LEVEL:  0  ITERATION:  62  METRIC:  -0.2650897736424575
# LEVEL:  0  ITERATION:  63  METRIC:  -0.2657426693493321
# LEVEL:  0  ITERATION:  64  METRIC:  -0.2664434073313919
# LEVEL:  0  ITERATION:  65  METRIC:  -0.26696476634249205
# LEVEL:  0  ITERATION:  66  METRIC:  -0.26738995859911785
# LEVEL:  0  ITERATION:  67  METRIC:  -0.26792626523823976
# LEVEL:  0  ITERATION:  68  METRIC:  -0.2685370774811952
# LEVEL:  0  ITERATION:  69  METRIC:  -0.2688510520205679
# LEVEL:  0  ITERATION:  70  METRIC:  -0.26932407388333623
# LEVEL:  0  ITERATION:  71  METRIC:  -0.26985870418092367
# LEVEL:  0  ITERATION:  72  METRIC:  -0.2704750327470948
# LEVEL:  0  ITERATION:  73  METRIC:  -0.2710451434605749
# LEVEL:  0  ITERATION:  74  METRIC:  -0.2717174926745029
# LEVEL:  0  ITERATION:  75  METRIC:  -0.2723692388787728
# LEVEL:  0  ITERATION:  76  METRIC:  -0.273033469870185
# LEVEL:  0  ITERATION:  77  METRIC:  -0.2736704416266248
# LEVEL:  0  ITERATION:  78  METRIC:  -0.27430250710090476
# LEVEL:  0  ITERATION:  79  METRIC:  -0.2749564676220161
# LEVEL:  0  ITERATION:  80  METRIC:  -0.27555581359869696
# LEVEL:  0  ITERATION:  81  METRIC:  -0.2762906208831384
# LEVEL:  0  ITERATION:  82  METRIC:  -0.27706691716171356
# LEVEL:  0  ITERATION:  83  METRIC:  -0.2775953700961164
# LEVEL:  0  ITERATION:  84  METRIC:  -0.2781276357456086
# LEVEL:  0  ITERATION:  85  METRIC:  -0.2789301256976504
# LEVEL:  0  ITERATION:  86  METRIC:  -0.2795378112271338
# LEVEL:  0  ITERATION:  87  METRIC:  -0.2801829100307008
# LEVEL:  0  ITERATION:  88  METRIC:  -0.2807920523451562
# LEVEL:  0  ITERATION:  89  METRIC:  -0.2814847686943173
# LEVEL:  0  ITERATION:  90  METRIC:  -0.2821667174303407
# LEVEL:  0  ITERATION:  91  METRIC:  -0.28298175550103666
# LEVEL:  0  ITERATION:  92  METRIC:  -0.28376423320270944
# LEVEL:  0  ITERATION:  93  METRIC:  -0.2846138888773048
# LEVEL:  0  ITERATION:  94  METRIC:  -0.2854434332612664
# LEVEL:  0  ITERATION:  95  METRIC:  -0.28627363248603205
# LEVEL:  0  ITERATION:  96  METRIC:  -0.2871931827155153
# LEVEL:  0  ITERATION:  97  METRIC:  -0.2878838558644268
# LEVEL:  0  ITERATION:  98  METRIC:  -0.288500946474978
# LEVEL:  0  ITERATION:  99  METRIC:  -0.28924872226160525
# LEVEL:  0  ITERATION:  100  METRIC:  -0.29001536970538616
# LEVEL:  0  ITERATION:  101  METRIC:  -0.2908003174297397
# LEVEL:  0  ITERATION:  102  METRIC:  -0.29155814620449866
# LEVEL:  0  ITERATION:  103  METRIC:  -0.29238998948238726
# LEVEL:  0  ITERATION:  104  METRIC:  -0.2932297884476764
# LEVEL:  0  ITERATION:  105  METRIC:  -0.29420577076275295
# LEVEL:  0  ITERATION:  106  METRIC:  -0.29517354468322593
# LEVEL:  0  ITERATION:  107  METRIC:  -0.2962243907464473
# LEVEL:  0  ITERATION:  108  METRIC:  -0.29723649580007827
# LEVEL:  0  ITERATION:  109  METRIC:  -0.29813771264271355
# LEVEL:  0  ITERATION:  110  METRIC:  -0.29909582847053146
# LEVEL:  0  ITERATION:  111  METRIC:  -0.30007911422912115
# LEVEL:  0  ITERATION:  112  METRIC:  -0.30095464535764815
# LEVEL:  0  ITERATION:  113  METRIC:  -0.3019028263210797
# LEVEL:  0  ITERATION:  114  METRIC:  -0.30279851559079635
# LEVEL:  0  ITERATION:  115  METRIC:  -0.3037245332866281
# LEVEL:  0  ITERATION:  116  METRIC:  -0.3047181568378873
# LEVEL:  0  ITERATION:  117  METRIC:  -0.30570027843813447
# LEVEL:  0  ITERATION:  118  METRIC:  -0.3067380701326527
# LEVEL:  0  ITERATION:  119  METRIC:  -0.3078627622732394
# LEVEL:  0  ITERATION:  120  METRIC:  -0.3090565985896164
# LEVEL:  0  ITERATION:  121  METRIC:  -0.3101242523111978
# LEVEL:  0  ITERATION:  122  METRIC:  -0.3112534479873523
# LEVEL:  0  ITERATION:  123  METRIC:  -0.31243924235622494
# LEVEL:  0  ITERATION:  124  METRIC:  -0.3136216247881533
# LEVEL:  0  ITERATION:  125  METRIC:  -0.3148196598092976
# LEVEL:  0  ITERATION:  126  METRIC:  -0.3159410269844745
# LEVEL:  0  ITERATION:  127  METRIC:  -0.31710721435008093
# LEVEL:  0  ITERATION:  128  METRIC:  -0.3182657821737708
# LEVEL:  0  ITERATION:  129  METRIC:  -0.3194499854653943
# LEVEL:  0  ITERATION:  130  METRIC:  -0.3207183850634424
# LEVEL:  0  ITERATION:  131  METRIC:  -0.3220608049322427
# LEVEL:  0  ITERATION:  132  METRIC:  -0.32344300909416923
# LEVEL:  0  ITERATION:  133  METRIC:  -0.3248347412951397
# LEVEL:  0  ITERATION:  134  METRIC:  -0.32624554311498793
# LEVEL:  0  ITERATION:  135  METRIC:  -0.32777264786642113
# LEVEL:  0  ITERATION:  136  METRIC:  -0.32918289257428934
# LEVEL:  0  ITERATION:  137  METRIC:  -0.3306250407467425
# LEVEL:  0  ITERATION:  138  METRIC:  -0.3320772376765156
# LEVEL:  0  ITERATION:  139  METRIC:  -0.3335489898004937
# LEVEL:  0  ITERATION:  140  METRIC:  -0.33501979622576067
# LEVEL:  0  ITERATION:  141  METRIC:  -0.3365062552785635
# LEVEL:  0  ITERATION:  142  METRIC:  -0.3379870129252017
# LEVEL:  0  ITERATION:  143  METRIC:  -0.3395405152540056
# LEVEL:  0  ITERATION:  144  METRIC:  -0.3411732021384572
# LEVEL:  0  ITERATION:  145  METRIC:  -0.3426104490720966
# LEVEL:  0  ITERATION:  146  METRIC:  -0.34397689649336327
# LEVEL:  0  ITERATION:  147  METRIC:  -0.3453918183196047
# LEVEL:  0  ITERATION:  148  METRIC:  -0.34689407783328824
# LEVEL:  0  ITERATION:  149  METRIC:  -0.34834880320948697
# LEVEL:  0  ITERATION:  150  METRIC:  -0.3500167260909196
# LEVEL:  0  ITERATION:  151  METRIC:  -0.35193217642074087
# LEVEL:  0  ITERATION:  152  METRIC:  -0.35395421679979117
# LEVEL:  0  ITERATION:  153  METRIC:  -0.35591396903165756
# LEVEL:  0  ITERATION:  154  METRIC:  -0.35777887577705736
# LEVEL:  0  ITERATION:  155  METRIC:  -0.3597792639810215
# LEVEL:  0  ITERATION:  156  METRIC:  -0.3616167388015262
# LEVEL:  0  ITERATION:  157  METRIC:  -0.36337354339243977
# LEVEL:  0  ITERATION:  158  METRIC:  -0.3650885960170508
# LEVEL:  0  ITERATION:  159  METRIC:  -0.36677844363178974
# LEVEL:  0  ITERATION:  160  METRIC:  -0.36837260802711297
# LEVEL:  0  ITERATION:  161  METRIC:  -0.3698970542698491
# LEVEL:  0  ITERATION:  162  METRIC:  -0.3713185731649158
# LEVEL:  0  ITERATION:  163  METRIC:  -0.372522198142743
# LEVEL:  0  ITERATION:  164  METRIC:  -0.3735523229907854
# LEVEL:  0  ITERATION:  165  METRIC:  -0.3746225688095903
# LEVEL:  0  ITERATION:  166  METRIC:  -0.37557306869383417
# LEVEL:  0  ITERATION:  167  METRIC:  -0.37645615372144453
# LEVEL:  0  ITERATION:  168  METRIC:  -0.37720789617969097
# LEVEL:  0  ITERATION:  169  METRIC:  -0.3778984243526296
# LEVEL:  0  ITERATION:  170  METRIC:  -0.3786652814317381
# LEVEL:  0  ITERATION:  171  METRIC:  -0.379583875569343
# LEVEL:  0  ITERATION:  172  METRIC:  -0.38145361365159897
# LEVEL:  0  ITERATION:  173  METRIC:  -0.3847900716148635
# LEVEL:  0  ITERATION:  174  METRIC:  -0.38744161994117127
# LEVEL:  0  ITERATION:  175  METRIC:  -0.38928823846572935
# LEVEL:  0  ITERATION:  176  METRIC:  -0.3905150705363227
# LEVEL:  0  ITERATION:  177  METRIC:  -0.39141614653031037
# LEVEL:  0  ITERATION:  178  METRIC:  -0.39254674378299903
# LEVEL:  0  ITERATION:  179  METRIC:  -0.39342874836435093
# LEVEL:  0  ITERATION:  180  METRIC:  -0.3945071743912671
# LEVEL:  0  ITERATION:  181  METRIC:  -0.39516259713400576
# LEVEL:  0  ITERATION:  182  METRIC:  -0.3966203190150864
# LEVEL:  0  ITERATION:  183  METRIC:  -0.3966280875000263
# LEVEL:  0  ITERATION:  184  METRIC:  -0.3972838287652655
# LEVEL:  0  ITERATION:  185  METRIC:  -0.39744005570149776
# LEVEL:  0  ITERATION:  186  METRIC:  -0.39760470345333365
# LEVEL:  0  ITERATION:  187  METRIC:  -0.39778610025850475
# LEVEL:  0  ITERATION:  188  METRIC:  -0.39795937533916464
# LEVEL:  0  ITERATION:  189  METRIC:  -0.3981182972733999
# LEVEL:  0  ITERATION:  190  METRIC:  -0.39829734150342294
# LEVEL:  0  ITERATION:  191  METRIC:  -0.39846767006604156
# LEVEL:  0  ITERATION:  192  METRIC:  -0.39876752794535686
# LEVEL:  0  ITERATION:  193  METRIC:  -0.39891396848845806
# LEVEL:  0  ITERATION:  194  METRIC:  -0.39935045454743645
# LEVEL:  0  ITERATION:  195  METRIC:  -0.39971056183456893
# LEVEL:  0  ITERATION:  196  METRIC:  -0.3998731121145286
# LEVEL:  0  ITERATION:  197  METRIC:  -0.400033470779811
# LEVEL:  0  ITERATION:  198  METRIC:  -0.40018942040188876
# LEVEL:  0  ITERATION:  199  METRIC:  -0.4003543353458424
# LEVEL:  0  ITERATION:  200  METRIC:  -0.40050820767631873
# LEVEL:  0  ITERATION:  201  METRIC:  -0.40067280422224216
# LEVEL:  0  ITERATION:  202  METRIC:  -0.4009421300099263
# LEVEL:  0  ITERATION:  203  METRIC:  -0.4011241958967327
# LEVEL:  0  ITERATION:  204  METRIC:  -0.4014756696416048
# LEVEL:  0  ITERATION:  205  METRIC:  -0.4017929875677379
# LEVEL:  0  ITERATION:  206  METRIC:  -0.4019649721230574
# LEVEL:  0  ITERATION:  207  METRIC:  -0.4021378777304794
# LEVEL:  0  ITERATION:  208  METRIC:  -0.4022802310105886
# LEVEL:  0  ITERATION:  209  METRIC:  -0.4024393905879738
# LEVEL:  0  ITERATION:  210  METRIC:  -0.4026066764105562
# LEVEL:  0  ITERATION:  211  METRIC:  -0.4027668126132385
# LEVEL:  0  ITERATION:  212  METRIC:  -0.4030507586217244
# LEVEL:  0  ITERATION:  213  METRIC:  -0.403219541586458
# LEVEL:  0  ITERATION:  214  METRIC:  -0.4034045810049235
# LEVEL:  0  ITERATION:  215  METRIC:  -0.40367019090202405
# LEVEL:  0  ITERATION:  216  METRIC:  -0.4039160604769845
# LEVEL:  0  ITERATION:  217  METRIC:  -0.40412294146715716
# LEVEL:  0  ITERATION:  218  METRIC:  -0.4043532679852852
# LEVEL:  0  ITERATION:  219  METRIC:  -0.4045598534098378
# LEVEL:  0  ITERATION:  220  METRIC:  -0.4046906756639996
# LEVEL:  0  ITERATION:  221  METRIC:  -0.4048337581999419
# LEVEL:  0  ITERATION:  222  METRIC:  -0.40498163219331507
# LEVEL:  0  ITERATION:  223  METRIC:  -0.4050896889680919
# LEVEL:  0  ITERATION:  224  METRIC:  -0.4052882675603807
# LEVEL:  0  ITERATION:  225  METRIC:  -0.40546361582603335
# LEVEL:  0  ITERATION:  226  METRIC:  -0.4055970229521349
# LEVEL:  0  ITERATION:  227  METRIC:  -0.4056518822526782
# LEVEL:  0  ITERATION:  228  METRIC:  -0.40573393291282656
# LEVEL:  0  ITERATION:  229  METRIC:  -0.4058195390022345
# LEVEL:  0  ITERATION:  230  METRIC:  -0.40587679063846666
# LEVEL:  0  ITERATION:  231  METRIC:  -0.40594512166613006
# LEVEL:  0  ITERATION:  232  METRIC:  -0.40596723673357354
# LEVEL:  0  ITERATION:  233  METRIC:  -0.40604272553803344
# LEVEL:  0  ITERATION:  234  METRIC:  -0.40612273719163516
# LEVEL:  0  ITERATION:  235  METRIC:  -0.4062054527497435
# LEVEL:  0  ITERATION:  236  METRIC:  -0.40628258591764904
# LEVEL:  0  ITERATION:  237  METRIC:  -0.40635514775935044
# LEVEL:  0  ITERATION:  238  METRIC:  -0.40644535017144523
# LEVEL:  0  ITERATION:  239  METRIC:  -0.4065142145803972
# LEVEL:  0  ITERATION:  240  METRIC:  -0.4065875820260189
# LEVEL:  0  ITERATION:  241  METRIC:  -0.4066662157102675
# LEVEL:  0  ITERATION:  242  METRIC:  -0.40673229143774436
# LEVEL:  0  ITERATION:  243  METRIC:  -0.40679542559707016
# LEVEL:  0  ITERATION:  244  METRIC:  -0.40685712066338087
# LEVEL:  0  ITERATION:  245  METRIC:  -0.40691374621277415
# LEVEL:  0  ITERATION:  246  METRIC:  -0.40697146758671543
# LEVEL:  0  ITERATION:  247  METRIC:  -0.4070232084311359
# LEVEL:  0  ITERATION:  248  METRIC:  -0.4070806353927111
# LEVEL:  0  ITERATION:  249  METRIC:  -0.4071395071522341
# LEVEL:  0  ITERATION:  250  METRIC:  -0.4071873732724576
# LEVEL:  0  ITERATION:  251  METRIC:  -0.40725298763294443
# LEVEL:  0  ITERATION:  252  METRIC:  -0.40728816441527815
# LEVEL:  0  ITERATION:  253  METRIC:  -0.4073385808153856
# LEVEL:  0  ITERATION:  254  METRIC:  -0.40736493309332006
# LEVEL:  0  ITERATION:  255  METRIC:  -0.4073935407398992
# LEVEL:  0  ITERATION:  256  METRIC:  -0.4074176177053562
# LEVEL:  0  ITERATION:  257  METRIC:  -0.40744190218085824
# LEVEL:  0  ITERATION:  258  METRIC:  -0.4074706068446966
# LEVEL:  0  ITERATION:  259  METRIC:  -0.4075178468488738
# LEVEL:  0  ITERATION:  260  METRIC:  -0.4075612550486143
# LEVEL:  0  ITERATION:  261  METRIC:  -0.40760001166709114
# LEVEL:  0  ITERATION:  262  METRIC:  -0.4076391267426949
# LEVEL:  0  ITERATION:  263  METRIC:  -0.4076637265838938
# LEVEL:  0  ITERATION:  264  METRIC:  -0.40769400125168326
# LEVEL:  0  ITERATION:  265  METRIC:  -0.40771075513532773
# LEVEL:  0  ITERATION:  266  METRIC:  -0.40770873261311014
# LEVEL:  0  ITERATION:  267  METRIC:  -0.4077301418046017
# LEVEL:  0  ITERATION:  268  METRIC:  -0.4077360249908559
# LEVEL:  0  ITERATION:  269  METRIC:  -0.40775471234081423
# LEVEL:  0  ITERATION:  270  METRIC:  -0.4077680489907309
# LEVEL:  0  ITERATION:  271  METRIC:  -0.4077857404671023
# LEVEL:  0  ITERATION:  272  METRIC:  -0.4078038536437975
# LEVEL:  0  ITERATION:  273  METRIC:  -0.40782210070060315
# LEVEL:  0  ITERATION:  274  METRIC:  -0.40784227582948696
# LEVEL:  0  ITERATION:  275  METRIC:  -0.4078518094039216
# LEVEL:  0  ITERATION:  276  METRIC:  -0.40786662440950683
# LEVEL:  0  ITERATION:  277  METRIC:  -0.4078820308995263
# LEVEL:  0  ITERATION:  278  METRIC:  -0.4078948578648947
# LEVEL:  0  ITERATION:  279  METRIC:  -0.4079084897662224
# LEVEL:  0  ITERATION:  280  METRIC:  -0.40793093373909517
# Registration succeeded
# CPU times: user 1min 10s, sys: 1.11 s, total: 1min 11s
# Wall time: 6.32 s

# %%
# apply transform and save results
affine_aligned = apply_transform(
    fix, mov,
    fix_spacing, mov_spacing,
    transform_list=[affine,],
)

# apply transform and save results
affine_aligned_seg = apply_transform(
    fix_seg, mov_seg,
    fix_spacing, mov_spacing,
    transform_list=[affine,],
    interpolate_with_nn=True,
)

# write results
np.savetxt('affine.mat', affine)
nrrd.write('./affine.nrrd', affine_aligned.transpose(2,1,0), compression_level=2)
nrrd.write('./affine_seg.nrrd', affine_aligned_seg.transpose(2,1,0), compression_level=2)

# load precomputed results
affine = np.loadtxt('./affine.mat')

# %%
from bigstream.utility import matrix_to_displacement_field

# load affine, convert to displacement, convert to voxel units
affine = np.loadtxt('./affine.mat')
deform = matrix_to_displacement_field(affine, fix.shape, spacing=fix_spacing)
deform = deform / fix_spacing

# save as h5 file
with h5py.File('./c_elegan_val.h5', 'w') as f:
    dset = f.create_dataset('pair4', deform.shape, deform.dtype)
    dset[...] = deform
